# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import jebas as jb
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Dados

# %%
franquias = pd.read_excel(
    'dados_mercado_franquia.xlsx',
    sheet_name='trimestre_python'                     
)

# %%
novo_periodo = {}
contador=1
for periodo in franquias['periodo'].unique():
    dict_temp = {periodo:contador}
    novo_periodo.update(dict_temp)
    contador +=1

franquias['novo_periodo'] = franquias['periodo'].map(novo_periodo)

# %%
franquias_tabela = pd.read_excel(
    'dados_mercado_franquia.xlsx',
    sheet_name='trimestre_visual',
    index_col=0                         
)

# %%
franquias.sample(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>segmento</th>
#       <th>periodo</th>
#       <th>faturamento</th>
#       <th>novo_periodo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23</th>
#       <td>TOTAL</td>
#       <td>2Tri2018</td>
#       <td>40753</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>TOTAL</td>
#       <td>3Tri2020</td>
#       <td>43954</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>Serviços educacionais</td>
#       <td>3Tri2020</td>
#       <td>2832</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>137</th>
#       <td>Limpeza e Conservação</td>
#       <td>4Tri2020</td>
#       <td>398</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Moda</td>
#       <td>1Tri2018</td>
#       <td>4418</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Hotelaria e Turismo</td>
#       <td>3Tri2018</td>
#       <td>3354</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>Saúde, Beleza e Bem Estar</td>
#       <td>1Tri2020</td>
#       <td>7622</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>Moda</td>
#       <td>3Tri2019</td>
#       <td>6105</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Alimentação</td>
#       <td>3Tri2018</td>
#       <td>11616</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Alimentação</td>
#       <td>1Tri2018</td>
#       <td>10590</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>123</th>
#       <td>Entretenimento e Lazer</td>
#       <td>3Tri2020</td>
#       <td>449</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Alimentação</td>
#       <td>2Tri2018</td>
#       <td>10954</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Limpeza e Conservação</td>
#       <td>3Tri2018</td>
#       <td>363</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Saúde, Beleza e Bem Estar</td>
#       <td>3Tri2018</td>
#       <td>7760</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Serviços e outros negócios</td>
#       <td>1Tri2018</td>
#       <td>5700</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>TOTAL</td>
#       <td>1Tri2018</td>
#       <td>38760</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Hotelaria e Turismo</td>
#       <td>2Tri2018</td>
#       <td>3239</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>Comunicação, Informática e Eletrônicos</td>
#       <td>3Tri2020</td>
#       <td>1535</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>Saúde, Beleza e Bem Estar</td>
#       <td>1Tri2019</td>
#       <td>7662</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Moda</td>
#       <td>4Tri2018</td>
#       <td>8205</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
franquias_tabela
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1Tri2018</th>
#       <th>2Tri2018</th>
#       <th>3Tri2018</th>
#       <th>4Tri2018</th>
#       <th>1Tri2019</th>
#       <th>2Tri2019</th>
#       <th>3Tri2019</th>
#       <th>4Tri2019</th>
#       <th>1Tri2020</th>
#       <th>2Tri2020</th>
#       <th>3Tri2020</th>
#       <th>4Tri2020</th>
#     </tr>
#     <tr>
#       <th>SEGMENTO</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Alimentação</th>
#       <td>10590</td>
#       <td>10954</td>
#       <td>11616</td>
#       <td>12667</td>
#       <td>10854</td>
#       <td>11546</td>
#       <td>12234</td>
#       <td>13765</td>
#       <td>10681</td>
#       <td>6286</td>
#       <td>10854</td>
#       <td>13077</td>
#     </tr>
#     <tr>
#       <th>Casa e Construção</th>
#       <td>1976</td>
#       <td>2443</td>
#       <td>2459</td>
#       <td>3142</td>
#       <td>2230</td>
#       <td>2579</td>
#       <td>2683</td>
#       <td>3527</td>
#       <td>2311</td>
#       <td>2122</td>
#       <td>3566</td>
#       <td>4430</td>
#     </tr>
#     <tr>
#       <th>Comunicação, Informática e Eletrônicos</th>
#       <td>1209</td>
#       <td>1280</td>
#       <td>1354</td>
#       <td>1642</td>
#       <td>1326</td>
#       <td>1377</td>
#       <td>1469</td>
#       <td>1862</td>
#       <td>1417</td>
#       <td>1248</td>
#       <td>1535</td>
#       <td>1863</td>
#     </tr>
#     <tr>
#       <th>Entretenimento e Lazer</th>
#       <td>576</td>
#       <td>491</td>
#       <td>584</td>
#       <td>786</td>
#       <td>616</td>
#       <td>507</td>
#       <td>601</td>
#       <td>844</td>
#       <td>611</td>
#       <td>49</td>
#       <td>449</td>
#       <td>713</td>
#     </tr>
#     <tr>
#       <th>Hotelaria e Turismo</th>
#       <td>2970</td>
#       <td>3239</td>
#       <td>3354</td>
#       <td>3069</td>
#       <td>3066</td>
#       <td>3290</td>
#       <td>3595</td>
#       <td>3335</td>
#       <td>3053</td>
#       <td>367</td>
#       <td>1224</td>
#       <td>2029</td>
#     </tr>
#     <tr>
#       <th>Limpeza e Conservação</th>
#       <td>307</td>
#       <td>341</td>
#       <td>363</td>
#       <td>375</td>
#       <td>321</td>
#       <td>349</td>
#       <td>380</td>
#       <td>401</td>
#       <td>339</td>
#       <td>233</td>
#       <td>347</td>
#       <td>398</td>
#     </tr>
#     <tr>
#       <th>Moda</th>
#       <td>4418</td>
#       <td>4686</td>
#       <td>5622</td>
#       <td>8205</td>
#       <td>4761</td>
#       <td>4868</td>
#       <td>6105</td>
#       <td>8494</td>
#       <td>4689</td>
#       <td>1519</td>
#       <td>4903</td>
#       <td>8043</td>
#     </tr>
#     <tr>
#       <th>Saúde, Beleza e Bem Estar</th>
#       <td>7019</td>
#       <td>7679</td>
#       <td>7760</td>
#       <td>9449</td>
#       <td>7662</td>
#       <td>8185</td>
#       <td>8127</td>
#       <td>10240</td>
#       <td>7622</td>
#       <td>7927</td>
#       <td>8930</td>
#       <td>10797</td>
#     </tr>
#     <tr>
#       <th>Serviços automotivos</th>
#       <td>1369</td>
#       <td>1505</td>
#       <td>1668</td>
#       <td>1352</td>
#       <td>1543</td>
#       <td>1566</td>
#       <td>1754</td>
#       <td>1453</td>
#       <td>1656</td>
#       <td>1233</td>
#       <td>1631</td>
#       <td>1453</td>
#     </tr>
#     <tr>
#       <th>Serviços e outros negócios</th>
#       <td>5700</td>
#       <td>5233</td>
#       <td>6628</td>
#       <td>7363</td>
#       <td>6247</td>
#       <td>5700</td>
#       <td>7026</td>
#       <td>8028</td>
#       <td>6219</td>
#       <td>4563</td>
#       <td>7683</td>
#       <td>8184</td>
#     </tr>
#     <tr>
#       <th>Serviços educacionais</th>
#       <td>2626</td>
#       <td>2902</td>
#       <td>3071</td>
#       <td>2801</td>
#       <td>2839</td>
#       <td>3155</td>
#       <td>3228</td>
#       <td>3017</td>
#       <td>2939</td>
#       <td>2173</td>
#       <td>2832</td>
#       <td>2990</td>
#     </tr>
#     <tr>
#       <th>TOTAL</th>
#       <td>38760</td>
#       <td>40753</td>
#       <td>44479</td>
#       <td>50851</td>
#       <td>41465</td>
#       <td>43122</td>
#       <td>47203</td>
#       <td>54965</td>
#       <td>41537</td>
#       <td>27720</td>
#       <td>43954</td>
#       <td>53977</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Análise exploratória

# %% [markdown]
# ## Linha do tempo de cada segmento

# %% [markdown]
# ### Variável

# %%
franquias_segmento = franquias.query('segmento!="TOTAL"')

# %%
grafico1 = sns.lineplot(
    x=franquias_segmento['periodo'],
    y=franquias_segmento['faturamento'],
    hue=franquias_segmento['segmento']        
)
grafico1.figure.set_size_inches(20,6)
grafico1.set_title('Gráfico 1 - Faturamento por período para cada segmento', color='r', fontsize=22)
grafico1.set_xlabel('Período', color='r', fontsize=18)
grafico1.set_ylabel('Faturamento', color='r', fontsize=18)
# Out:
# Text(0, 0.5, 'Faturamento')

# %%
grafico2 = sns.boxplot(
    data=franquias_segmento,
    x=franquias_segmento['segmento'],
    y=franquias_segmento['faturamento']            
)
grafico2.figure.set_size_inches(20,6)
grafico2.set_title('Gráfico 2 - Boxplot por segmento', color='r', fontsize=22)
grafico2.set_xlabel('Segmento', color='r', fontsize=18)
grafico2.set_ylabel('Faturamento', color='r', fontsize=18)
plt.show()

# %% [markdown]
# OBS.:
# * alguns segmentos seguem a mesma tendência ao longo do desenvolvimento temporal
#     * alimentação, saúde, hotelaria, educacionais - tiveram um grande impacto negativo no primeiro semestre de 2020
#     * saúde, aparentemente, não teve tanto impacto em relação ao covid
# * embora todos os segmentos apresentem curvas similares, há grande diferença em termos de dispersão dos dados
#     * moda, por exemplo, possui uma forte assimetria a esquerda, enquanto serviços apresenta uma curva normal

# %% [markdown]
# ## Análise por segmento

# %% [markdown]
# ### Variáveis

# %%
print(f'Selecionar valores de acordo com a lista:\n{franquias.segmento.unique()}')
# Out:
# Selecionar valores de acordo com a lista:
# ['Alimentação' 'Casa e Construção'
#  'Comunicação, Informática e Eletrônicos' 'Entretenimento e Lazer'
#  'Hotelaria e Turismo' 'Limpeza e Conservação' 'Moda'
#  'Saúde, Beleza e Bem Estar' 'Serviços automotivos'
#  'Serviços e outros negócios' 'Serviços educacionais' 'TOTAL']

# %%
selecao = 'TOTAL'
franquia_selecao = franquias.query('segmento==@selecao')

# %%
jb.medidas_dispersao(list(franquia_selecao['faturamento']))
# Out:
# Amplitude                     27245.00
# Desvio Padrão                  7345.06
# Desvio Padrão (+)             51410.56
# Desvio Padrão (-)             36720.44
# Coeficiente de Variação(%)       16.67
# Assimetria                       -0.47
# dtype: float64

# %%
jb.medidas_posicao(list(franquia_selecao['faturamento']))
# Out:
# Moda                       -
# Média                44065.5
# Mediana                43538
# Mediana(menor)         43122
# Mediana(maior)         43954
# 1° quartil             41465
# 2° quartil             43954
# 3° quartil             50851
# Amplitude quartil       9386
# dtype: object

# %%
grafico3 = sns.distplot(
    franquia_selecao['faturamento'],
    bins=10,
    norm_hist=True
)
grafico3.figure.set_size_inches(20,6)
grafico3.set_title('Gráfico 3 - Dispersão acumulada do faturamento por trimestre', color='r', fontsize=22)
grafico3.set_xlabel('Faturamento', color='r', fontsize=18)
grafico3.set_ylabel('Densidade', color='r', fontsize=18)
plt.show()
# Out:
# /opt/anaconda3/envs/datalore-user/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
grafico4 = sns.distplot(
    franquia_selecao['faturamento'],
    bins=10,
    norm_hist=True,
    kde_kws={'cumulative':True},
    hist_kws={'cumulative':True}
)
grafico4.figure.set_size_inches(20,6)
grafico4.set_title('Gráfico 4 - Dispersão acumulada do faturamento por trimestre', color='r', fontsize=22)
grafico4.set_xlabel('Faturamento', color='r', fontsize=18)
grafico4.set_ylabel('Frequencia', color='r', fontsize=18)
plt.show()
# Out:
# /opt/anaconda3/envs/datalore-user/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
grafico5 = sns.lineplot(
    data=franquia_selecao,
    x=franquia_selecao['novo_periodo'],
    y=franquia_selecao['faturamento'],
    markers=True
)
grafico5.figure.set_size_inches(20,6)
grafico5.set_title('Gráfico 5 - Faturamento por trimestre', color='r', fontsize=22)
grafico5.set_xlabel('Faturamento', color='r', fontsize=18)
grafico5.set_ylabel('Frequencia', color='r', fontsize=18)
grafico5.axis(ymin=0, ymax=franquia_selecao['faturamento'].max() * 1.2)
plt.show()

# %% [markdown]
# ## Autocorrelação

# %%
from pandas.plotting import autocorrelation_plot

# %%
grafico6 = plt.figure(figsize=(20,6))
grafico6.suptitle('Gráfico 6 - Auto-correlação Faturamento', color='r', fontsize=22)
autocorrelation_plot(franquia_selecao['faturamento'])
plt.show()

# %% [markdown]
# # Regressão e Previsão

# %% [markdown]
# # Statsmodels

# %% [markdown]
# ## Teste 1 - Base completa

# %% [markdown]
# ## Preparação dos dados

# %%
import statsmodels.api as sm

# %%
Y = franquia_selecao['faturamento']
X = sm.add_constant(franquia_selecao['novo_periodo'])

# %% [markdown]
# ## Regressão

# %%
resultado_regressao = sm.OLS(Y, X, missing='drop').fit()

# %%
resultado_regressao.params
# Out:
# const           42317.909091
# novo_periodo      268.860140
# dtype: float64

# %%
resultado_regressao.conf_int()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>const</th>
#       <td>31846.223420</td>
#       <td>52789.594761</td>
#     </tr>
#     <tr>
#       <th>novo_periodo</th>
#       <td>-1153.961763</td>
#       <td>1691.682043</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
franquia_selecao['y_previsao'] = resultado_regressao.predict()
franquia_selecao['residuo'] = resultado_regressao.resid
franquia_selecao
# Out:
# /opt/anaconda3/envs/datalore-user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/datalore-user/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>segmento</th>
#       <th>periodo</th>
#       <th>faturamento</th>
#       <th>novo_periodo</th>
#       <th>y_previsao</th>
#       <th>residuo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>TOTAL</td>
#       <td>1Tri2018</td>
#       <td>38760</td>
#       <td>1</td>
#       <td>42586.769231</td>
#       <td>-3826.769231</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>TOTAL</td>
#       <td>2Tri2018</td>
#       <td>40753</td>
#       <td>2</td>
#       <td>42855.629371</td>
#       <td>-2102.629371</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>TOTAL</td>
#       <td>3Tri2018</td>
#       <td>44479</td>
#       <td>3</td>
#       <td>43124.489510</td>
#       <td>1354.510490</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>TOTAL</td>
#       <td>4Tri2018</td>
#       <td>50851</td>
#       <td>4</td>
#       <td>43393.349650</td>
#       <td>7457.650350</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>TOTAL</td>
#       <td>1Tri2019</td>
#       <td>41465</td>
#       <td>5</td>
#       <td>43662.209790</td>
#       <td>-2197.209790</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>TOTAL</td>
#       <td>2Tri2019</td>
#       <td>43122</td>
#       <td>6</td>
#       <td>43931.069930</td>
#       <td>-809.069930</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>TOTAL</td>
#       <td>3Tri2019</td>
#       <td>47203</td>
#       <td>7</td>
#       <td>44199.930070</td>
#       <td>3003.069930</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>TOTAL</td>
#       <td>4Tri2019</td>
#       <td>54965</td>
#       <td>8</td>
#       <td>44468.790210</td>
#       <td>10496.209790</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>TOTAL</td>
#       <td>1Tri2020</td>
#       <td>41537</td>
#       <td>9</td>
#       <td>44737.650350</td>
#       <td>-3200.650350</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>TOTAL</td>
#       <td>2Tri2020</td>
#       <td>27720</td>
#       <td>10</td>
#       <td>45006.510490</td>
#       <td>-17286.510490</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>TOTAL</td>
#       <td>3Tri2020</td>
#       <td>43954</td>
#       <td>11</td>
#       <td>45275.370629</td>
#       <td>-1321.370629</td>
#     </tr>
#     <tr>
#       <th>143</th>
#       <td>TOTAL</td>
#       <td>4Tri2020</td>
#       <td>53977</td>
#       <td>12</td>
#       <td>45544.230769</td>
#       <td>8432.769231</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
grafico7_a = sns.lineplot(
    data=franquia_selecao,             
    x=franquia_selecao['novo_periodo'],             
    y=franquia_selecao['faturamento']             
)
grafico7_b = sns.lineplot(
    data=franquia_selecao,             
    x=franquia_selecao['novo_periodo'],             
    y=franquia_selecao['y_previsao']             
)
grafico7_a.figure.set_size_inches(20,6)
grafico7_a.set_title('Gráfico 7 - Checagem Regressão Linear', color='r', fontsize=22)
grafico7_a.set_xlabel('Faturamento', color='r', fontsize=18)
grafico7_a.set_ylabel('Frequencia', color='r', fontsize=18)
grafico7_a.axis(ymin=0, ymax=franquia_selecao['faturamento'].max() * 1.2)
plt.show()

# %%
franquia_selecao['residuo'].mean()
# Out:
# -1.39455854271849e-11

# %% [markdown]
# ### Previsão

# %% [markdown]
# ### Variáveis

# %%
previsao = resultado_regressao.predict([1,13])[0]
dicionario_previsao = {
    'segmento':[selecao],
    'periodo':['1Tri2021'],
    'novo_periodo':[12],
    'faturamento':[previsao],
    'y_previsao':[previsao]                       
}
df_previsão = pd.DataFrame(
    data=dicionario_previsao                    
)

# %%
franquia_selecao_previsao = pd.concat([franquia_selecao,df_previsão])
franquia_selecao_previsao
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>segmento</th>
#       <th>periodo</th>
#       <th>faturamento</th>
#       <th>novo_periodo</th>
#       <th>y_previsao</th>
#       <th>residuo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>TOTAL</td>
#       <td>1Tri2018</td>
#       <td>38760.000000</td>
#       <td>1</td>
#       <td>42586.769231</td>
#       <td>-3826.769231</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>TOTAL</td>
#       <td>2Tri2018</td>
#       <td>40753.000000</td>
#       <td>2</td>
#       <td>42855.629371</td>
#       <td>-2102.629371</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>TOTAL</td>
#       <td>3Tri2018</td>
#       <td>44479.000000</td>
#       <td>3</td>
#       <td>43124.489510</td>
#       <td>1354.510490</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>TOTAL</td>
#       <td>4Tri2018</td>
#       <td>50851.000000</td>
#       <td>4</td>
#       <td>43393.349650</td>
#       <td>7457.650350</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>TOTAL</td>
#       <td>1Tri2019</td>
#       <td>41465.000000</td>
#       <td>5</td>
#       <td>43662.209790</td>
#       <td>-2197.209790</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>TOTAL</td>
#       <td>2Tri2019</td>
#       <td>43122.000000</td>
#       <td>6</td>
#       <td>43931.069930</td>
#       <td>-809.069930</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>TOTAL</td>
#       <td>3Tri2019</td>
#       <td>47203.000000</td>
#       <td>7</td>
#       <td>44199.930070</td>
#       <td>3003.069930</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>TOTAL</td>
#       <td>4Tri2019</td>
#       <td>54965.000000</td>
#       <td>8</td>
#       <td>44468.790210</td>
#       <td>10496.209790</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>TOTAL</td>
#       <td>1Tri2020</td>
#       <td>41537.000000</td>
#       <td>9</td>
#       <td>44737.650350</td>
#       <td>-3200.650350</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>TOTAL</td>
#       <td>2Tri2020</td>
#       <td>27720.000000</td>
#       <td>10</td>
#       <td>45006.510490</td>
#       <td>-17286.510490</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>TOTAL</td>
#       <td>3Tri2020</td>
#       <td>43954.000000</td>
#       <td>11</td>
#       <td>45275.370629</td>
#       <td>-1321.370629</td>
#     </tr>
#     <tr>
#       <th>143</th>
#       <td>TOTAL</td>
#       <td>4Tri2020</td>
#       <td>53977.000000</td>
#       <td>12</td>
#       <td>45544.230769</td>
#       <td>8432.769231</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>TOTAL</td>
#       <td>1Tri2021</td>
#       <td>45813.090909</td>
#       <td>12</td>
#       <td>45813.090909</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
grafico8 = sns.lineplot(
    data=franquia_selecao_previsao,             
    x=franquia_selecao_previsao['periodo'],             
    y=franquia_selecao_previsao['faturamento']             
)
grafico8 = sns.lineplot(
    data=franquia_selecao_previsao,             
    x=franquia_selecao_previsao['periodo'],             
    y=franquia_selecao_previsao['y_previsao']
)    
grafico8.figure.set_size_inches(20,6)
grafico8.set_title('Gráfico 8 - Previsão para o 1° trimestre de 2021', color='r', fontsize=22)
grafico8.set_xlabel('Período', color='r', fontsize=18)
grafico8.set_ylabel('Faturamento', color='r', fontsize=18)
grafico8.axis(ymin=0, ymax=franquia_selecao['faturamento'].max() * 1.2)
plt.show()

# %% [markdown]
# ### Variação

# %%
variacao = franquia_selecao.query('periodo in ["1Tri2018", "1Tri2019", "4Tri2020"]')[['periodo','faturamento']]
variacao['Previsão %'] = (1 - (variacao['faturamento'] / previsao)) * 100
variacao
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>periodo</th>
#       <th>faturamento</th>
#       <th>Previsão %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>1Tri2018</td>
#       <td>38760</td>
#       <td>15.395361</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>1Tri2019</td>
#       <td>41465</td>
#       <td>9.490936</td>
#     </tr>
#     <tr>
#       <th>143</th>
#       <td>4Tri2020</td>
#       <td>53977</td>
#       <td>-17.820036</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
resultado_regressao.rsquared * 100
# Out:
# 1.7418267060790749

# %%
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            faturamento   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.081
# Method:                 Least Squares   F-statistic:                    0.1773
# Date:                Wed, 17 Mar 2021   Prob (F-statistic):              0.683
# Time:                        12:18:44   Log-Likelihood:                -123.22
# No. Observations:                  12   AIC:                             250.4
# Df Residuals:                      10   BIC:                             251.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         4.232e+04   4699.746      9.004      0.000    3.18e+04    5.28e+04
# novo_periodo   268.8601    638.570      0.421      0.683   -1153.962    1691.682
# ==============================================================================
# Omnibus:                        4.396   Durbin-Watson:                   1.636
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                1.536
# Skew:                          -0.757   Prob(JB):                        0.464
# Kurtosis:                       3.883   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/anaconda3/envs/datalore-user/lib/python3.7/site-packages/scipy/stats/stats.py:1604: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
